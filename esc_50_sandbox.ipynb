# %%
import pandas as pd

meta = pd.read_csv('data/ESC-50-master/meta/esc50.csv')

animal_classes = [
    'dog',
    'chirping_birds',
    'crow',
    'sheep',
    'frog',
    'cow',
    'hen',
    'pig',
    'rooster',
    'cat',
    'crickets',
]

animal_subset = meta[meta['category'].isin(animal_classes)]
animal_subset = animal_subset.reset_index(drop=True)

target_dict = {}
for animal in animal_classes:
    target_dict[animal] = int(animal_subset[animal_subset['category'] == animal]['target'].iloc[0])

animal_subset
# Out:
#               filename  fold  target        category  esc10  src_file take
# 0     1-100032-A-0.wav     1       0             dog   True    100032    A
# 1    1-100038-A-14.wav     1      14  chirping_birds  False    100038    A
# 2     1-103298-A-9.wav     1       9            crow  False    103298    A
# 3     1-110389-A-0.wav     1       0             dog   True    110389    A
# 4     1-121951-A-8.wav     1       8           sheep  False    121951    A
# ..                 ...   ...     ...             ...    ...       ...  ...
# 475   5-261325-A-9.wav     5       9            crow  False    261325    A
# 476   5-263831-A-6.wav     5       6             hen  False    263831    A
# 477   5-263831-B-6.wav     5       6             hen  False    263831    B
# 478    5-61635-A-8.wav     5       8           sheep  False     61635    A
# 479     5-9032-A-0.wav     5       0             dog   True      9032    A
#
# [480 rows x 7 columns]

# %%
import torchaudio
from IPython.display import Audio

# Load audio
waveform, orig_sr = torchaudio.load("data/ESC-50-master/audio/1-30226-A-0.wav")
Audio(waveform.numpy(), rate=orig_sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
waveform.shape[0]
# Out:
# 1
